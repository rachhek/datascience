# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
house_df = pd.read_csv("./datasets/kc_house_data.csv")
house_df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
house_df.shape
# Out:
# (21597, 21)

# %%
house_df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
house_df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# ## Data Preprocessing

# %%
house_df = house_df.drop(['id','date','zipcode'],axis=1)
house_df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
house_df['age'] = 2018 - house_df['yr_built']
house_df = house_df.drop('yr_built',axis=1)
house_df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_renovated      lat  \
# 0     0          3      7        1180              0             0  47.5112
# 1     0          3      7        2170            400          1991  47.7210
# 2     0          3      6         770              0             0  47.7379
# 3     0          5      7        1050            910             0  47.5208
# 4     0          3      8        1680              0             0  47.6168
#
#       long  sqft_living15  sqft_lot15  age
# ...

# %%
house_df['renovated'] = house_df['yr_renovated'].apply(lambda x:1 if x>0 else 0)
house_df=house_df.drop('yr_renovated',axis=1)
house_df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement      lat     long  \
# 0     0          3      7        1180              0  47.5112 -122.257
# 1     0          3      7        2170            400  47.7210 -122.319
# 2     0          3      6         770              0  47.7379 -122.233
# 3     0          5      7        1050            910  47.5208 -122.393
# 4     0          3      8        1680              0  47.6168 -122.045
#
#    sqft_living15  sqft_lot15  age  renovated
# ...

# %%
house_df.to_csv("./datasets/house_data_preprocessed.csv",index=False)

# %%
house_df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  2.159700e+04
# mean   5.402966e+05      3.373200      2.115826   2080.321850  1.509941e+04
# std    3.673681e+05      0.926299      0.768984    918.106125  4.141264e+04
# min    7.800000e+04      1.000000      0.500000    370.000000  5.200000e+02
# 25%    3.220000e+05      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068500e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21597.000000  21597.000000  21597.000000  21597.000000  21597.000000
# mean       1.494096      0.007547      0.234292      3.409825      7.657915
# ...

# %%
plt.scatter(house_df['bedrooms'],house_df['bathrooms'])
plt.xlabel("bedrooms")
plt.ylabel("bathrooms")

# %%
plt.scatter(house_df['sqft_living'],house_df['price'])
plt.xlabel("sqft_living")
plt.ylabel("price")
# Out:
# Text(0,0.5,'price')

# %%
house_df_corr = house_df.corr()
house_df_corr
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308787   0.525906     0.701917  0.089876  0.256804
# bedrooms       0.308787  1.000000   0.514508     0.578212  0.032471  0.177944
# bathrooms      0.525906  0.514508   1.000000     0.755758  0.088373  0.502582
# sqft_living    0.701917  0.578212   0.755758     1.000000  0.173453  0.353953
# sqft_lot       0.089876  0.032471   0.088373     0.173453  1.000000 -0.004814
# floors         0.256804  0.177944   0.502582     0.353953 -0.004814  1.000000
# waterfront     0.266398 -0.006834   0.063744     0.103854  0.021632  0.023755
# view           0.397370  0.080008   0.188386     0.284709  0.074900  0.028814
# condition      0.036056  0.026496  -0.126479    -0.059445 -0.008830 -0.264075
# grade          0.667951  0.356563   0.665838     0.762779  0.114731  0.458794
# sqft_above     0.605368  0.479386   0.686668     0.876448  0.184139  0.523989
# ...

# %%
fig,ax = plt.subplots(figsize=(10,8))
sns.heatmap(house_df_corr)

# %% [markdown]
# ## Modelling

# %%
from sklearn.model_selection import train_test_split
X = house_df.drop('price',axis=1)
Y = house_df['price']

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
reg_model = LinearRegression().fit(x_train,y_train)

# %%
print("Training score : ", reg_model.score(x_train,y_train))
#regression model uses r-square to evaluate the model. Basically r-square gives the value of how of the 
# underlying variance is captured by our model
# Out:
# Training score :  0.6957993627048402

# %%
predictors = x_train.columns
coef = pd.Series(reg_model.coef_,predictors).sort_values()
print(coef)
# Out:
# long            -117020.007507
# bedrooms         -35803.813557
# sqft_lot15           -0.401563
# sqft_lot              0.139893
# sqft_living15        26.311555
# sqft_basement        39.480291
# sqft_above           69.552995
# sqft_living         109.033286
# age                2499.465441
# floors             3764.461291
# condition         32614.485419
# renovated         41743.706692
# bathrooms         42972.191829
# view              48790.853452
# grade             97887.550744
# lat              551880.741873
# waterfront       561316.647496
# dtype: float64

# %%
y_pred = reg_model.predict(x_test)

# %%
from sklearn.metrics import r2_score
print("Testing score :" , r2_score(y_test,y_pred))
# Out:
# Testing score : 0.6953204573034694

# %%
import statsmodels.api as sm
x_train_with_const = sm.add_constant(x_train)
model = sm.OLS(y_train,x_train_with_const)
#OLS = Ordinary Least Square

# %%
result = model.fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.696
# Model:                            OLS   Adj. R-squared:                  0.696
# Method:                 Least Squares   F-statistic:                     2467.
# Date:                Sun, 12 Jan 2020   Prob (F-statistic):               0.00
# Time:                        13:30:20   Log-Likelihood:            -2.3549e+05
# No. Observations:               17277   AIC:                         4.710e+05
# Df Residuals:                   17260   BIC:                         4.711e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -4.139e+07   1.71e+06    -24.175      0.000   -4.47e+07    -3.8e+07
# ...

# %% [markdown]
# R-squared value : This value shows how well our model captured the underlying data.
# Adjusted R-Square value : this is a modification of R-square. This value will fall if we have features in our dataset that does not add value.
# F-statistic and Prob shows the significance of our result. High value of f-statistic with low value of probability tell that our test is significant.
# P-value shows that probability that our score was obtained by chance. Low P-value is good
